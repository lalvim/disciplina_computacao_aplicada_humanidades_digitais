# %% [markdown]
# # Oficina — Relatório exploratório
#
# [▶ Abrir este notebook no Google Colab](https://colab.research.google.com/github/lalvim/disciplina_computacao_aplicada_humanidades_digitais/blob/main/unidade_04/04_oficina_relatorio_exploratorio.ipynb)
# Roteiro discursivo; execute análises em notebook próprio.

# %% [markdown]
# ## Escopo e qualidade
# Pergunta, corpus, unidade, cobertura, variáveis, ausências, extremos e erros: Escreva aqui.

# %% [markdown]
# ## Perfil quantitativo
# Frequências/proporções; centro/dispersão; distribuição; extremos; contingência; descrição e interpretação: Escreva aqui.

# %% [markdown]
# ## Perfil textual
# Regras; frequências; concordâncias; n-gramas; colocações; diversidade e tamanho: Escreva aqui.

# %% [markdown]
# ## Visualizações
# Inclua quatro famílias com tabela, descrição alternativa, interpretação e limite. Escreva aqui.

# %% [markdown]
# ## Retorno aos casos
# Escolha três documentos ou trechos que qualifiquem agregados. Escreva aqui.

# %% [markdown]
# ## Hipóteses provisórias
# Até três hipóteses com evidência, alternativas, dados adicionais e método futuro. Escreva aqui.

# %% [markdown]
# ## Rubrica e entrega
# Avalie de 0 a 2: escopo, estatística, texto, visualização/acessibilidade, casos, limites e reprodutibilidade. A Unidade 5 tratará inferência. Escreva aqui.
